# %%
import os
import pandas as pd
import openpyxl

# %% [markdown]
# #Importar o ficheiro Transportes

# %%
import os
import pandas as pd

# Caminho da pasta 
folder_path = os.path.join(os.path.expanduser("~"), "Desktop", "New folder")

# Obter o primeiro ficheiro encontrado na pasta
files = os.listdir(folder_path)
if not files:
    raise FileNotFoundError("Nenhum ficheiro encontrado na pasta.")

file_path = os.path.join(folder_path, files[0])
print(f"A abrir ficheiro: {file_path}")

# Detectar extensão e abrir no Pandas
ext = os.path.splitext(file_path)[1].lower()

if ext in [".csv", ".txt"]:
    df_transportes = pd.read_csv(file_path)
elif ext in [".xls", ".xlsx"]:
    df_transportes = pd.read_excel(file_path)
else:
    raise ValueError(f"Formato de ficheiro não suportado: {ext}")
# Out:
# A abrir ficheiro: C:\Users\1420844\Desktop\New folder\Estrutura Carreiras.xlsx

# %%
df.head()
# Out:
#                               Name Category__c   Area__c Capacity__c  \
# 0                           EPA 14     Primary  Nacional       Heavy
# 1                       EPA 09 (2)     Primary  Nacional       Heavy
# 2  CPLS / COS / EPA 00 (3ª a 6ªF)      Primary  Nacional       Heavy
# 3              EPA / COS 00 (2ªF)      Primary  Nacional       Heavy
# 4    COS / CO OPL / COS 23:30 (RB)     Primary  Nacional       Heavy
#
#   Execution_Mode__c                              Observations__c  \
# 0             Rigid  Toda la ruta se encuentra en horas locales.
# 1             Rigid  Toda la ruta se encuentra en horas locales.
# 2             Rigid  Toda la ruta se encuentra en horas locales.
# 3             Rigid  Toda la ruta se encuentra en horas locales.
# 4             Rigid  Toda la ruta se encuentra en horas locales.
#
#   Operational_Center_Agency__r.Name Operational_Center_Agency__c  \
# 0             C.O. Rutas Nacionales                          RNA
# 1             C.O. Rutas Nacionales                          RNA
# 2             C.O. Rutas Nacionales                          RNA
# 3             C.O. Rutas Nacionales                          RNA
# 4             C.O. Rutas Nacionales                          RNA
#
#   Periodicity__c                Provider__r.Name  ... MMA__c  Payload__c  \
# 0          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 1          Fixed  CTT - Correios de Portugal S.A  ...  10000        2000
# 2          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 3          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 4          Fixed            Campos & Cadilhe Lda  ...  20000        5000
#
#   Number_Of_pallets__c  SemiTruck__c Vehicle_Type__c   Pay_Way__c  \
# 0                 16.0         False           Rigid  Transfer_65
# 1                  8.0         False           Rigid  Transfer_65
# 2                 16.0         False           Rigid  Transfer_65
# 3                 16.0         False           Rigid  Transfer_65
# 4                 16.0         False           Rigid  Transfer_65
#
#   contract_start_day__c  route_start_day__c delivery_senda__c  \
# 0            2024-07-12          2024-07-12             False
# 1            2024-07-12          2024-07-12             False
# 2            2024-07-12          2024-07-12             False
# 3            2024-07-12          2024-07-12             False
# 4            2024-07-12          2024-07-12             False
#
#         RecordTypeId
# 0  0123X000000eQqAQAU
# 1  0123X000000eQqAQAU
# 2  0123X000000eQqAQAU
# 3  0123X000000eQqAQAU
# 4  0123X000000eQqAQAU
#
# [5 rows x 36 columns]

# %% [markdown]
# #Importar modelo Portal

# %%
import os
import pandas as pd

# Caminho da pasta 
folder_path = os.path.join(os.path.expanduser("~"), "Desktop", "New folder (2)")

# Obter o primeiro ficheiro encontrado na pasta
files = os.listdir(folder_path)
if not files:
    raise FileNotFoundError("Nenhum ficheiro encontrado na pasta.")

file_path = os.path.join(folder_path, files[0])
print(f"A abrir ficheiro: {file_path}")

# Ler todas as folhas do Excel
df_portal = pd.read_excel(file_path, sheet_name=None)  # None -> lê todas as sheets

sheet_names = pd.ExcelFile(file_path).sheet_names




# Detectar extensão e abrir no Pandas
ext = os.path.splitext(file_path)[1].lower()

if ext in [".csv", ".txt"]:
    df_portal = pd.read_csv(file_path)
elif ext in [".xls", ".xlsx"]:
    df_portal = pd.read_excel(file_path)
else:
    raise ValueError(f"Formato de ficheiro não suportado: {ext}")
# Out:
# A abrir ficheiro: C:\Users\1420844\Desktop\New folder (2)\Linehaul PT - Plantilla Carga - Rutas, Trayectos, Paradas_Base de produção 6_8_2024.xlsx

# %%
# Imprimir nomes
print("Folhas no ficheiro:")
for name in sheet_names:
    print("-", name)
# Out:
# Folhas no ficheiro:
# - Rutas
# - trayect
# - paradas

# %%
# Ler apenas a folha "Rutas"
df_portal_Rutas = pd.read_excel(file_path, sheet_name="Rutas")
df_portal_Rutas.head()
# Out:
#                               Name Category__c   Area__c Capacity__c  \
# 0                           EPA 14     Primary  Nacional       Heavy
# 1                       EPA 09 (2)     Primary  Nacional       Heavy
# 2  CPLS / COS / EPA 00 (3ª a 6ªF)      Primary  Nacional       Heavy
# 3              EPA / COS 00 (2ªF)      Primary  Nacional       Heavy
# 4    COS / CO OPL / COS 23:30 (RB)     Primary  Nacional       Heavy
#
#   Execution_Mode__c                              Observations__c  \
# 0             Rigid  Toda la ruta se encuentra en horas locales.
# 1             Rigid  Toda la ruta se encuentra en horas locales.
# 2             Rigid  Toda la ruta se encuentra en horas locales.
# 3             Rigid  Toda la ruta se encuentra en horas locales.
# 4             Rigid  Toda la ruta se encuentra en horas locales.
#
#   Operational_Center_Agency__r.Name Operational_Center_Agency__c  \
# 0             C.O. Rutas Nacionales                          RNA
# 1             C.O. Rutas Nacionales                          RNA
# 2             C.O. Rutas Nacionales                          RNA
# 3             C.O. Rutas Nacionales                          RNA
# 4             C.O. Rutas Nacionales                          RNA
#
#   Periodicity__c                Provider__r.Name  ... MMA__c  Payload__c  \
# 0          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 1          Fixed  CTT - Correios de Portugal S.A  ...  10000        2000
# 2          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 3          Fixed  CTT - Correios de Portugal S.A  ...  20000        5000
# 4          Fixed            Campos & Cadilhe Lda  ...  20000        5000
#
#   Number_Of_pallets__c  SemiTruck__c Vehicle_Type__c   Pay_Way__c  \
# 0                 16.0         False           Rigid  Transfer_65
# 1                  8.0         False           Rigid  Transfer_65
# 2                 16.0         False           Rigid  Transfer_65
# 3                 16.0         False           Rigid  Transfer_65
# 4                 16.0         False           Rigid  Transfer_65
#
#   contract_start_day__c  route_start_day__c delivery_senda__c  \
# 0            2024-07-12          2024-07-12             False
# 1            2024-07-12          2024-07-12             False
# 2            2024-07-12          2024-07-12             False
# 3            2024-07-12          2024-07-12             False
# 4            2024-07-12          2024-07-12             False
#
#         RecordTypeId
# 0  0123X000000eQqAQAU
# 1  0123X000000eQqAQAU
# 2  0123X000000eQqAQAU
# 3  0123X000000eQqAQAU
# 4  0123X000000eQqAQAU
#
# [5 rows x 36 columns]

# %%
# Ler apenas a folha "Rutas"
df_portal_Rutas = pd.read_excel(file_path, sheet_name="trayect")
df_portal_Rutas.head()
# Out:
#                                 Name           Parent_Service__r.Name  \
# 0                           EPA 14_0                           EPA 14
# 1                       EPA 09 (2)_0                       EPA 09 (2)
# 2  CPLS / COS / EPA 00 (3ª a 6ªF) _0  CPLS / COS / EPA 00 (3ª a 6ªF)
# 3              EPA / COS 00 (2ªF) _0              EPA / COS 00 (2ªF)
# 4    COS / CO OPL / COS 23:30 (RB)_0    COS / CO OPL / COS 23:30 (RB)
#
#    Observations__c  Cost_Center__c Category__c   Area__c Capacity__c  \
# 0              NaN       6161136.0     Primary  Nacional       Heavy
# 1              NaN       6161136.0     Primary  Nacional       Heavy
# 2              NaN       6161136.0     Primary  Nacional       Heavy
# 3              NaN       6161136.0     Primary  Nacional       Heavy
# 4              NaN       6161136.0     Primary  Nacional       Heavy
#
#   Execution_Mode__c National_Route_Type__c Zone__c  ... Number_Of_pallets__c  \
# 0             Rigid                  Fixed     Sur  ...                 16.0
# 1             Rigid                  Fixed     Sur  ...                  8.0
# 2             Rigid                  Fixed     Sur  ...                 16.0
# 3             Rigid                  Fixed     Sur  ...                 16.0
# 4             Rigid                  Fixed     Sur  ...                 16.0
#
#   SemiTruck__c   Pay_Way__c  contracted_tons__c cost_euro_kg__c  \
# 0        False  Transfer_65                 5.0            0.06
# 1        False  Transfer_65                 2.0            0.15
# 2        False  Transfer_65                 5.0            0.06
# 3        False  Transfer_65                 5.0            0.06
# 4        False  Transfer_65                 5.0            0.06
#
#   cost_euro_ton__c  euros_tn_km__c tn_km_contractet__c total_amount_day__c  \
# 0             60.0       27.272727                55.0                 300
# 1            150.0        9.090909                66.0                 300
# 2             60.0        5.084746               295.0                 300
# 3             60.0        6.382979               235.0                 300
# 4             60.0       10.000000               150.0                 300
#
#          RecordTypeId
# 0  0123X000000SM4SQAW
# 1  0123X000000SM4SQAW
# 2  0123X000000SM4SQAW
# 3  0123X000000SM4SQAW
# 4  0123X000000SM4SQAW
#
# [5 rows x 43 columns]

# %%
# Ler apenas a folha "Rutas"
df_portal_Rutas = pd.read_excel(file_path, sheet_name="paradas")
df_portal_Rutas.head()
# Out:
#                      Name Service__r.Name  Service__r.Service_Code__c  \
# 0                Cpls Sul        EPA 14_0                         NaN
# 1  EPA - AEROPORTO LISBOA        EPA 14_0                         NaN
# 2                Cpls Sul        EPA 14_0                         NaN
# 3                Cpls Sul    EPA 09 (2)_0                         NaN
# 4  EPA - AEROPORTO LISBOA    EPA 09 (2)_0                         NaN
#
#    Service__c  Ratio__c  Access_Conditions__c  Allowed_Access_Vehicle_Type__c  \
# 0         NaN       NaN                   NaN                             NaN
# 1         NaN       NaN                   NaN                             NaN
# 2         NaN       NaN                   NaN                             NaN
# 3         NaN       NaN                   NaN                             NaN
# 4         NaN       NaN                   NaN                             NaN
#
#    Actual_Arrival_Time__c  Actual_Departure_Time__c  Day__c  ...  \
# 0                     NaN                       NaN       0  ...
# 1                     NaN                       NaN       0  ...
# 2                     NaN                       NaN       0  ...
# 3                     NaN                       NaN       0  ...
# 4                     NaN                       NaN       0  ...
#
#    Kilometer__c Operative_Center__r.Name Operative_Center__c  Order__c  \
# 0            15                 Cpls Sul             8811360         1
# 1            30   EPA - AEROPORTO LISBOA                1309         2
# 2            30                 Cpls Sul             8811360         3
# 3            15                 Cpls Sul             8811360         1
# 4            30   EPA - AEROPORTO LISBOA                1309         2
#
#   Operative_Center_Province__c  \
# 0                          SLX
# 1                          SLX
# 2                          SLX
# 3                          SLX
# 4                          SLX
#
#                                      Load_Centers__c   Load_Order__c  \
# 0                             EPA - AEROPORTO LISBOA            1309
# 1                                           Cpls Sul         8811360
# 2                                                NaN             NaN
# 3  EPA - AEROPORTO LISBOA;EPA - AEROPORTO LISBOA;...  1309;1309;1309
# 4                                           Cpls Sul         8811360
#
#         Unload_Centers__c Unload_Order__c RecordType.DeveloperName
# 0                     NaN             NaN             Loading_Plan
# 1  EPA - AEROPORTO LISBOA            1309             Loading_Plan
# 2  EPA - AEROPORTO LISBOA            1309             Loading_Plan
# 3                     NaN             NaN             Loading_Plan
# 4  EPA - AEROPORTO LISBOA            1309             Loading_Plan
#
# [5 rows x 23 columns]
